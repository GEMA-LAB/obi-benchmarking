# %% [markdown]
# # Métricas do sistemas
# ---

# %% [markdown]
# ### Bibliotecas
#
# ---
#
# Caso não consiga instalar execute `pip install -r requirements.txt` no terminal

# %%
# !uv pip install -r ../requirements.txt
# Out:
# Using Python 3.14.3 environment at: c:\Users\Victo\Desktop\Ufal\obi-benchmarking\venv
# Resolved 117 packages in 1.43s
# Downloading openai (1.6MiB)
# Downloading matplotlib (9.0MiB)
# Downloading numpy (12.0MiB)
# Downloading pandas (9.4MiB)
# Downloading notebook (5.3MiB)
# Downloading fonttools (2.2MiB)
# Downloading pywinpty (2.0MiB)
# Downloading jupyterlab (16.4MiB)
# Downloading pillow (6.9MiB)
#  Downloaded openai
#  Downloaded pywinpty
#  Downloaded fonttools
#  Downloaded notebook
#  Downloaded pillow
#  Downloaded matplotlib
#  Downloaded pandas
#  Downloaded numpy
#  Downloaded jupyterlab
# Prepared 33 packages in 16.98s
# Installed 88 packages in 6.66s
#  + annotated-types==0.7.0
#  + anyio==4.14.1
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + async-lru==2.3.0
#  + attrs==26.1.0
#  + babel==2.18.0
#  + beautifulsoup4==4.15.0
#  + bleach==6.4.0
#  + certifi==2026.6.17
#  + cffi==2.1.0
#  + charset-normalizer==3.4.9
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + defusedxml==0.7.1
#  + distro==1.9.0
#  + fastjsonschema==2.21.2
#  + fonttools==4.63.0
#  + fqdn==1.5.1
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.18
#  + ipywidgets==8.1.8
#  + isoduration==20.11.0
#  + jinja2==3.1.6
#  + jiter==0.16.0
#  + json5==0.15.0
#  + jsonpointer==3.1.1
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + jupyter==1.1.1
#  + jupyter-builder==1.0.2
#  + jupyter-console==6.6.3
#  + jupyter-events==0.12.1
#  + jupyter-lsp==2.3.1
#  + jupyter-server==2.20.0
#  + jupyter-server-terminals==0.5.4
#  + jupyterlab==4.6.1
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.28.0
#  + jupyterlab-widgets==3.0.16
#  + kiwisolver==1.5.0
#  + lark==1.3.1
#  + markupsafe==3.0.3
#  + matplotlib==3.11.0
#  + mistune==3.3.3
#  + nbclient==0.11.0
#  + nbconvert==7.17.1
#  + nbformat==5.10.4
#  + notebook==7.6.0
#  + notebook-shim==0.2.4
#  + numpy==2.5.1
#  + openai==2.45.0
#  + pandas==3.0.3
#  + pandocfilters==1.5.1
#  + pillow==12.3.0
#  + prometheus-client==0.25.0
#  + pycparser==3.0
#  + pydantic==2.13.4
#  + pydantic-core==2.46.4
#  + pydantic-settings==2.14.2
#  + pyparsing==3.3.2
#  + python-dotenv==1.2.2
#  + python-json-logger==4.1.0
#  + pywinpty==3.0.5
#  + pyyaml==6.0.3
#  + referencing==0.37.0
#  + requests==2.34.2
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rpds-py==2026.6.3
#  + send2trash==2.1.0
#  + sniffio==1.3.1
#  + soupsieve==2.8.4
#  + terminado==0.18.1
#  + tinycss2==1.5.1
#  + tqdm==4.68.4
#  + typing-inspection==0.4.2
#  + tzdata==2026.3
#  + uri-template==1.3.0
#  + urllib3==2.7.0
#  + webcolors==25.10.0
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
#  + widgetsnbextension==4.0.15

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# %%
path_database = Path("../database")
questions_path = []
        
for folder in list(path_database.iterdir()):
    if folder.is_dir():
        questions_path.append(folder)
        
problems = []
questions_name = []
for question_path in questions_path:
    
    path_imgs = question_path / "imgs"
    path_test_cases = question_path / "test_cases"
    
    if path_test_cases.exists() and path_imgs.exists():
        questions_name.append(question_path.name)
        problems.append(json.loads(Path(question_path / "problem.json").read_text(encoding="utf-8")))
        
print(f"Quantidade de problemas com imagens: {len(problems)}")
# Out:
# Quantidade de problemas com imagens: 181

# %%
for problem in problems:
    print(problem["title"])
# Out:
# Acelerador de partículas
# Amigos
# Arco e flecha
# Atlanta
# Atletismo
# Avenida
# Avião
# Baldes
# Basquete de robôs
# Bingo!
# Bolas
# Bombom
# Bondinho
# Brigadeiros
# Burocracia
# Cabo de guerra
# Cadeado
# Cadeiras do auditório
# Caixinha de palitos
# Calçada Imperial
# Caminho das Pontes
# Caminhos do reino
# Campeonato
# Campo de Minhocas
# Campo Minado
# Capitais
# Carro elétrico
# Cartas
# Casamento de inteiros
# Castelos da Nlogônia
# Catálogo de Músicas
# Cavalos
# Caça ao Tesouro
# Caçadores de Mitos
# Chinelos
# Chocolate
# Chocolate em barra
# Chuva
# Chuva
# Cinco
# Cinema
# Competição de chocolate
# Computador
# Construção de Rodovia
# Conta de água
# Copa
# Copa do Mundo
# Corredor
# Cortando o Papel
# Costa
# Cubo Preto
# Cubra os Furos
# Cápsulas
# Câmara de Compensação
# Câmeras
# Dança de Formatura
# Dança Indígena
# Dario e Xerxes
# Dengue
# Diagonal
# Distância entre amigos
# Dividindo o império
# Dobradura
# Dominó
# Dominó
# Dona Minhoca
# Duende Perdido
# Elevador
# Entrega de Caixas
# Escada perfeita
# Escher
# Estoque
# Falta uma
# Fast-Food
# Fila
# Fissura Perigosa
# Fitas Verde-amarelas
# Floresta
# Flíper
# Forja de ORicalco
# Frete
# Frete da Família Silva
# Fuga
# Fuga com helicóptero
# Game Show
# Game-10
# Gomoku
# Gráfico de Barras
# Impedido!
# Jardim de infância
# Jogo da Vida
# Jogo de Cartas
# Jogo de Dominós
# Jogo de Tabuleiro
# Jogo do Preto e Branco
# Jogo dos copos
# Jogo dos Pinos
# Linhas Cruzadas
# Linhas de Ônibus
# Macaco-prego
# Macacos me mordam!
# Mancha
# Manchas de pele
# Medalhas
# Mesa redonda
# Metrô da Nlogônia
# Metrônibus
# Mina
# Montanha
# Muro
# Móbile
# Móbile
# Nota cortada
# Notas da Prova
# Nova avenida
# O Chefe
# O Tabuleiro Esburacado
# Palavras Cruzadas
# Passa Bolinha
# Passatempo
# Pesos
# Piloto Automático
# Pirâmide
# Pirâmide
# Piso da escola
# Pizza
# Pizzaria
# Ponto do meio
# Proteja sua senha
# Pulo do Gato
# Quadrado
# Quadrado Aritmético
# Quadrado Mágico
# Quadrado Mágico
# Quebra-cabeça
# Rede ótica
# Redes de Descanso
# Reduzindo detalhes em um mapa
# Relógios
# Remove Dígitos
# Retas
# Retângulo
# Robô
# Rodovia
# Segredo do Cofre
# Semente
# Sequência Secreta
# Setas
# Sinuca
# Soma
# Sr. Sapo
# Sr. Toupeira
# Supermercado
# Taxa
# Teclado
# Telefone
# Teleférico
# Tesouro
# Tiro ao Alvo
# Toca do Saci
# Torre
# Torres de Hanói
# Toupeira
# Transmissão de Energia
# Transporte de Contêineres
# Transportes
# Trilhas
# Trio de Bonecas
# Trio de Palitinhos
# Triângulos
# Troca
# TV da Vovó
# VAR
# Viagem
# Visita entre cidades
# Wifi
# Xadrez
# Xadrez Aleatório
# Zero para cancelar
# Álbum de fotos
# Ônibus

# %%
df_problems = pd.DataFrame(problems)
counts_difficulty = {}

for d in df_problems["difficulty"].unique():
    cases = df_problems[df_problems["difficulty"] == d]
    counts_difficulty[d] = len(cases)
    
print(counts_difficulty)
# Out:
# {'Fácil': 67, 'Médio': 81, 'Difícil': 33}

# %%
X = ["Fácil", "Médio", "Difícil"]
y = [counts_difficulty[x] for x in X]

print(y)
print(X)
plt.figure(figsize=(8, 6))

bar_plot = plt.bar(X, y, color=['green', 'yellow', 'blue'], edgecolor='black')

plt.bar_label(bar_plot, padding=3)

plt.title("Classificação das questões pelo modelo Gemini 3.1 Pro")
plt.ylabel('Quantidade de Problemas')
plt.show()
# Out:
# [67, 81, 33]
# ['Fácil', 'Médio', 'Difícil']

# %% [markdown]
# ### PROMPT: QUESTÕES COM IMAGENS NA BASE64 vs QUESTÕES SEM IMAGENS
# ---

# %%
files_path = Path("../output/multimodal/results/")
dataset = {}

count_total_tokens = {}

for path in files_path.rglob("*"):
    if not path.is_file():
        continue
    
    df = pd.read_csv(path)
    
    name = path.name.replace(".csv", "")
    count_total_tokens[name] = 0
    
    dataset[name] = df
    
    for value in df["total_tokens"]:
        count_total_tokens[name] += value
        
for key, value in count_total_tokens.items():
    print(f"file: {key} | total de tokens: {value}")
# Out:
# file: results_anthropic_claude_sonnet_4_6_python_zero_img | total de tokens: 370949
# file: results_anthropic_claude_sonnet_4_6_python_zero_noimg | total de tokens: 307314
# file: results_google_gemini_3_1_pro_preview_python_zero_img | total de tokens: 1183470
# file: results_google_gemini_3_1_pro_preview_python_zero_noimg | total de tokens: 928250
# file: results_gpt_5_4_python_zero_img | total de tokens: 240511
# file: results_gpt_5_4_python_zero_noimg | total de tokens: 203283
# file: results_mistralai_mistral_small_2603_python_zero_img | total de tokens: 263588
# file: results_mistralai_mistral_small_2603_python_zero_noimg | total de tokens: 219431
# file: results_x_ai_grok_4_20_python_zero_img | total de tokens: 324413
# file: results_x_ai_grok_4_20_python_zero_noimg | total de tokens: 354468

# %%
def success_rate_in_case_tests(files_path: Path = Path('../output/multimodal/results/'), type: str = '_img'):
    
    dataset = {}
    for path in files_path.rglob('*'):
        if not path.is_file():
            continue

        parts = str(path).split("results_")
        if len(parts) < 2:
            continue
                    
        if not (type in path.name):
            continue
            
        if path.stat().st_size == 0:
            print(f"⚠️ Arquivo vazio ignorado: {path.name}")
            continue

        try:
            df = pd.read_csv(path)
            model_name = path.name.replace(".csv", "")
            
            print(model_name)
            if model_name not in dataset:
                dataset[model_name] = df
            else:
                dataset[model_name] = pd.concat([dataset[model_name], df], ignore_index=True)
            
        except ValueError as e:
            print(f"Erro de ValueError (JSON malformado) no arquivo: {path.name}")
            print(f"   -> Detalhe: {e}")
        except Exception as e:
            print(f"Erro inesperado ao ler {path.name}: {e}")

    count = 0
    keys = list(dataset.keys())
    for data in dataset[keys[0]]["total_test_cases"]:
        count += data
    
    print("Total de caso testes: ", count)
    rows = []
    for model, data in dataset.items():
        rows.append({
            "Modelo": model,
            "AC":  data["AC"].sum()  / count,
            "WA":  data["WA"].sum()  / count,
            "RE":  data["RE"].sum()  / count,
            "TLE": data["TLE"].sum() / count,
            "CE":  data["CE"].sum()  / count,
        })

    df_results = pd.DataFrame(rows)

    display(
        df_results.style
        .format({
            "AC":  "{:.2%}",
            "WA":  "{:.2%}",
            "RE":  "{:.2%}",
            "TLE": "{:.2%}",
            "CE":  "{:.2%}",
        })
    )

# %%
#colocar com _type
success_rate_in_case_tests(type='_img')
# Out:
# results_anthropic_claude_sonnet_4_6_python_zero_img
# results_google_gemini_3_1_pro_preview_python_zero_img
# results_gpt_5_4_python_zero_img
# results_mistralai_mistral_small_2603_python_zero_img
# results_x_ai_grok_4_20_python_zero_img
# Total de caso testes:  6704
# <style type="text/css">
# </style>
# <table id="T_85a48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85a48_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_85a48_level0_col1" class="col_heading level0 col1" >AC</th>
#       <th id="T_85a48_level0_col2" class="col_heading level0 col2" >WA</th>
#       <th id="T_85a48_level0_col3" class="col_heading level0 col3" >RE</th>
#       <th id="T_85a48_level0_col4" class="col_heading level0 col4" >TLE</th>
#       <th id="T_85a48_level0_col5" class="col_heading level0 col5" >CE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85a48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85a48_row0_col0" class="data row0 col0" >results_anthropic_claude_sonnet_4_6_python_zero_img</td>
#       <td id="T_85a48_row0_col1" class="data row0 col1" >80.44%</td>
#       <td id="T_85a48_row0_col2" class="data row0 col2" >5.28%</td>
#       <td id="T_85a48_row0_col3" class="data row0 col3" >11.11%</td>
#       <td id="T_85a48_row0_col4" class="data row0 col4" >3.16%</td>
#       <td id="T_85a48_row0_col5" class="data row0 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_85a48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85a48_row1_col0" class="data row1 col0" >results_google_gemini_3_1_pro_preview_python_zero_img</td>
#       <td id="T_85a48_row1_col1" class="data row1 col1" >96.38%</td>
#       <td id="T_85a48_row1_col2" class="data row1 col2" >2.88%</td>
#       <td id="T_85a48_row1_col3" class="data row1 col3" >0.36%</td>
#       <td id="T_85a48_row1_col4" class="data row1 col4" >0.39%</td>
#       <td id="T_85a48_row1_col5" class="data row1 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_85a48_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85a48_row2_col0" class="data row2 col0" >results_gpt_5_4_python_zero_img</td>
#       <td id="T_85a48_row2_col1" class="data row2 col1" >79.13%</td>
#       <td id="T_85a48_row2_col2" class="data row2 col2" >17.91%</td>
#       <td id="T_85a48_row2_col3" class="data row2 col3" >2.19%</td>
#       <td id="T_85a48_row2_col4" class="data row2 col4" >0.76%</td>
#       <td id="T_85a48_row2_col5" class="data row2 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_85a48_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85a48_row3_col0" class="data row3 col0" >results_mistralai_mistral_small_2603_python_zero_img</td>
#       <td id="T_85a48_row3_col1" class="data row3 col1" >55.70%</td>
#       <td id="T_85a48_row3_col2" class="data row3 col2" >32.94%</td>
#       <td id="T_85a48_row3_col3" class="data row3 col3" >6.67%</td>
#       <td id="T_85a48_row3_col4" class="data row3 col4" >4.70%</td>
#       <td id="T_85a48_row3_col5" class="data row3 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_85a48_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85a48_row4_col0" class="data row4 col0" >results_x_ai_grok_4_20_python_zero_img</td>
#       <td id="T_85a48_row4_col1" class="data row4 col1" >65.14%</td>
#       <td id="T_85a48_row4_col2" class="data row4 col2" >22.88%</td>
#       <td id="T_85a48_row4_col3" class="data row4 col3" >7.71%</td>
#       <td id="T_85a48_row4_col4" class="data row4 col4" >4.33%</td>
#       <td id="T_85a48_row4_col5" class="data row4 col5" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
success_rate_in_case_tests(type='_noimg')
# Out:
# results_anthropic_claude_sonnet_4_6_python_zero_noimg
# results_google_gemini_3_1_pro_preview_python_zero_noimg
# results_gpt_5_4_python_zero_noimg
# results_mistralai_mistral_small_2603_python_zero_noimg
# results_x_ai_grok_4_20_python_zero_noimg
# Total de caso testes:  6708
# <style type="text/css">
# </style>
# <table id="T_1762d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1762d_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_1762d_level0_col1" class="col_heading level0 col1" >AC</th>
#       <th id="T_1762d_level0_col2" class="col_heading level0 col2" >WA</th>
#       <th id="T_1762d_level0_col3" class="col_heading level0 col3" >RE</th>
#       <th id="T_1762d_level0_col4" class="col_heading level0 col4" >TLE</th>
#       <th id="T_1762d_level0_col5" class="col_heading level0 col5" >CE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1762d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1762d_row0_col0" class="data row0 col0" >results_anthropic_claude_sonnet_4_6_python_zero_noimg</td>
#       <td id="T_1762d_row0_col1" class="data row0 col1" >80.90%</td>
#       <td id="T_1762d_row0_col2" class="data row0 col2" >6.71%</td>
#       <td id="T_1762d_row0_col3" class="data row0 col3" >8.35%</td>
#       <td id="T_1762d_row0_col4" class="data row0 col4" >4.04%</td>
#       <td id="T_1762d_row0_col5" class="data row0 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1762d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1762d_row1_col0" class="data row1 col0" >results_google_gemini_3_1_pro_preview_python_zero_noimg</td>
#       <td id="T_1762d_row1_col1" class="data row1 col1" >96.33%</td>
#       <td id="T_1762d_row1_col2" class="data row1 col2" >2.91%</td>
#       <td id="T_1762d_row1_col3" class="data row1 col3" >0.42%</td>
#       <td id="T_1762d_row1_col4" class="data row1 col4" >0.34%</td>
#       <td id="T_1762d_row1_col5" class="data row1 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1762d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1762d_row2_col0" class="data row2 col0" >results_gpt_5_4_python_zero_noimg</td>
#       <td id="T_1762d_row2_col1" class="data row2 col1" >77.73%</td>
#       <td id="T_1762d_row2_col2" class="data row2 col2" >18.89%</td>
#       <td id="T_1762d_row2_col3" class="data row2 col3" >2.52%</td>
#       <td id="T_1762d_row2_col4" class="data row2 col4" >0.86%</td>
#       <td id="T_1762d_row2_col5" class="data row2 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1762d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1762d_row3_col0" class="data row3 col0" >results_mistralai_mistral_small_2603_python_zero_noimg</td>
#       <td id="T_1762d_row3_col1" class="data row3 col1" >60.87%</td>
#       <td id="T_1762d_row3_col2" class="data row3 col2" >29.55%</td>
#       <td id="T_1762d_row3_col3" class="data row3 col3" >5.50%</td>
#       <td id="T_1762d_row3_col4" class="data row3 col4" >4.08%</td>
#       <td id="T_1762d_row3_col5" class="data row3 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_1762d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1762d_row4_col0" class="data row4 col0" >results_x_ai_grok_4_20_python_zero_noimg</td>
#       <td id="T_1762d_row4_col1" class="data row4 col1" >61.76%</td>
#       <td id="T_1762d_row4_col2" class="data row4 col2" >23.20%</td>
#       <td id="T_1762d_row4_col3" class="data row4 col3" >10.96%</td>
#       <td id="T_1762d_row4_col4" class="data row4 col4" >4.08%</td>
#       <td id="T_1762d_row4_col5" class="data row4 col5" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
def average(data):
    n = len(data)
    count = 0
    
    for value in data:
        count += value
        
    return float(count/n)

# %%
def per_ac_questions(data):
    n = len(data)
    count = 0
    for value in data["judge_predict"]:
        if value == "AC":
            count += 1
            
    return float(count/n)

# %%
def table_with_info(type: str = "_img"):
    files_path = Path("../output/multimodal/results/")

    dataset = {}

    for path in list(files_path.rglob('*')):        
        model = str(path).split("results_")[1]
        if not type in model:
            continue
        
        model = model.split("_python_zero")[0]
        
        dataset[model] = pd.read_csv(path)
    
    metrics = {}

    for key, data in dataset.items():
        
        row = {}
        
        hard_questions = data[data["difficulty"] == "Difícil"]
        row['hard_ac'] = per_ac_questions(hard_questions)
        
        medium_questions = data[data["difficulty"] == "Médio"]
        row['medium_ac'] = per_ac_questions(medium_questions)
        
        easy_questions = data[data["difficulty"] == "Fácil"]
        row['easy_ac'] = per_ac_questions(easy_questions)
        
        row['avg_tokens'] = average(data["total_tokens"])
        row['avg_cost'] = average(data["cost_prompt"])
        row['avg_create_code'] = average(data["llm_code_creation_time"])
        
        metrics[key] = row
    
    rows = []
    names_model = {
        "anthropic_claude_sonnet_4_6": "Claude Sonnet 4.6",
        "gpt_5_4": "GPT 5.4",
        "x_ai_grok_4_20": "Grok 4.20",
        "google_gemini_3_1_pro_preview": "Gemini 3.1 Pro",
        "mistralai_mistral_small_2603": "Mistral Small 4"
    }

    for key, data in metrics.items():
        rows.append({
            "Modelo":               names_model[key],
            "Fácil AC (%)":         data["easy_ac"] * 100,
            "Média AC (%)":         data["medium_ac"] * 100,
            "Difícil AC (%)":       data["hard_ac"] * 100,
            "Tokens (Média)":       data["avg_tokens"],
            "Custo Médio (US$)":    data["avg_cost"],
            "Tempo Médio (s)":      data["avg_create_code"], 
        })

    df = pd.DataFrame(rows).sort_values("Modelo").reset_index(drop=True)

    display(
        df.style
        .format({
            "Fácil AC (%)":       "{:.2f}",
            "Média AC (%)":       "{:.2f}",
            "Difícil AC (%)":     "{:.2f}",
            "Tokens (Média)":     "{:.0f}",
            "Custo Médio (US$)":  "{:.4f}",
            "Tempo Médio (s)":    "{:.0f}",
        })
        .set_properties(**{'text-align': 'center'})
        .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
        .hide(axis="index")
    )
    
    rows = []
    for key, data in metrics.items():
        # Tratamento preventivo caso algum modelo do dicionário não tenha sido processado no arquivo
        if key in names_model:
            rows.append({
                "Modelo":               names_model[key],
                "Fácil AC (%)":         data["easy_ac"] * 100,
                "Média AC (%)":         data["medium_ac"] * 100,
                "Difícil AC (%)":       data["hard_ac"] * 100,
            })

    return pd.DataFrame(rows)

# %%
question_img = table_with_info("_img")
# Out:
# <style type="text/css">
# #T_ea70b th {
#   text-align: center;
# }
# #T_ea70b_row0_col0, #T_ea70b_row0_col1, #T_ea70b_row0_col2, #T_ea70b_row0_col3, #T_ea70b_row0_col4, #T_ea70b_row0_col5, #T_ea70b_row0_col6, #T_ea70b_row1_col0, #T_ea70b_row1_col1, #T_ea70b_row1_col2, #T_ea70b_row1_col3, #T_ea70b_row1_col4, #T_ea70b_row1_col5, #T_ea70b_row1_col6, #T_ea70b_row2_col0, #T_ea70b_row2_col1, #T_ea70b_row2_col2, #T_ea70b_row2_col3, #T_ea70b_row2_col4, #T_ea70b_row2_col5, #T_ea70b_row2_col6, #T_ea70b_row3_col0, #T_ea70b_row3_col1, #T_ea70b_row3_col2, #T_ea70b_row3_col3, #T_ea70b_row3_col4, #T_ea70b_row3_col5, #T_ea70b_row3_col6, #T_ea70b_row4_col0, #T_ea70b_row4_col1, #T_ea70b_row4_col2, #T_ea70b_row4_col3, #T_ea70b_row4_col4, #T_ea70b_row4_col5, #T_ea70b_row4_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_ea70b">
#   <thead>
#     <tr>
#       <th id="T_ea70b_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_ea70b_level0_col1" class="col_heading level0 col1" >Fácil AC (%)</th>
#       <th id="T_ea70b_level0_col2" class="col_heading level0 col2" >Média AC (%)</th>
#       <th id="T_ea70b_level0_col3" class="col_heading level0 col3" >Difícil AC (%)</th>
#       <th id="T_ea70b_level0_col4" class="col_heading level0 col4" >Tokens (Média)</th>
#       <th id="T_ea70b_level0_col5" class="col_heading level0 col5" >Custo Médio (US$)</th>
#       <th id="T_ea70b_level0_col6" class="col_heading level0 col6" >Tempo Médio (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea70b_row0_col0" class="data row0 col0" >Claude Sonnet 4.6</td>
#       <td id="T_ea70b_row0_col1" class="data row0 col1" >83.58</td>
#       <td id="T_ea70b_row0_col2" class="data row0 col2" >71.60</td>
#       <td id="T_ea70b_row0_col3" class="data row0 col3" >30.30</td>
#       <td id="T_ea70b_row0_col4" class="data row0 col4" >2049</td>
#       <td id="T_ea70b_row0_col5" class="data row0 col5" >0.0148</td>
#       <td id="T_ea70b_row0_col6" class="data row0 col6" >12</td>
#     </tr>
#     <tr>
#       <td id="T_ea70b_row1_col0" class="data row1 col0" >GPT 5.4</td>
#       <td id="T_ea70b_row1_col1" class="data row1 col1" >82.09</td>
#       <td id="T_ea70b_row1_col2" class="data row1 col2" >69.14</td>
#       <td id="T_ea70b_row1_col3" class="data row1 col3" >30.30</td>
#       <td id="T_ea70b_row1_col4" class="data row1 col4" >1329</td>
#       <td id="T_ea70b_row1_col5" class="data row1 col5" >0.0065</td>
#       <td id="T_ea70b_row1_col6" class="data row1 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_ea70b_row2_col0" class="data row2 col0" >Gemini 3.1 Pro</td>
#       <td id="T_ea70b_row2_col1" class="data row2 col1" >97.01</td>
#       <td id="T_ea70b_row2_col2" class="data row2 col2" >87.65</td>
#       <td id="T_ea70b_row2_col3" class="data row2 col3" >78.79</td>
#       <td id="T_ea70b_row2_col4" class="data row2 col4" >6539</td>
#       <td id="T_ea70b_row2_col5" class="data row2 col5" >0.0567</td>
#       <td id="T_ea70b_row2_col6" class="data row2 col6" >39</td>
#     </tr>
#     <tr>
#       <td id="T_ea70b_row3_col0" class="data row3 col0" >Grok 4.20</td>
#       <td id="T_ea70b_row3_col1" class="data row3 col1" >73.13</td>
#       <td id="T_ea70b_row3_col2" class="data row3 col2" >53.09</td>
#       <td id="T_ea70b_row3_col3" class="data row3 col3" >15.15</td>
#       <td id="T_ea70b_row3_col4" class="data row3 col4" >1792</td>
#       <td id="T_ea70b_row3_col5" class="data row3 col5" >0.0061</td>
#       <td id="T_ea70b_row3_col6" class="data row3 col6" >7</td>
#     </tr>
#     <tr>
#       <td id="T_ea70b_row4_col0" class="data row4 col0" >Mistral Small 4</td>
#       <td id="T_ea70b_row4_col1" class="data row4 col1" >61.19</td>
#       <td id="T_ea70b_row4_col2" class="data row4 col2" >41.98</td>
#       <td id="T_ea70b_row4_col3" class="data row4 col3" >12.12</td>
#       <td id="T_ea70b_row4_col4" class="data row4 col4" >1456</td>
#       <td id="T_ea70b_row4_col5" class="data row4 col5" >0.0018</td>
#       <td id="T_ea70b_row4_col6" class="data row4 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
question_noimg = table_with_info("_noimg")
# Out:
# <style type="text/css">
# #T_094a7 th {
#   text-align: center;
# }
# #T_094a7_row0_col0, #T_094a7_row0_col1, #T_094a7_row0_col2, #T_094a7_row0_col3, #T_094a7_row0_col4, #T_094a7_row0_col5, #T_094a7_row0_col6, #T_094a7_row1_col0, #T_094a7_row1_col1, #T_094a7_row1_col2, #T_094a7_row1_col3, #T_094a7_row1_col4, #T_094a7_row1_col5, #T_094a7_row1_col6, #T_094a7_row2_col0, #T_094a7_row2_col1, #T_094a7_row2_col2, #T_094a7_row2_col3, #T_094a7_row2_col4, #T_094a7_row2_col5, #T_094a7_row2_col6, #T_094a7_row3_col0, #T_094a7_row3_col1, #T_094a7_row3_col2, #T_094a7_row3_col3, #T_094a7_row3_col4, #T_094a7_row3_col5, #T_094a7_row3_col6, #T_094a7_row4_col0, #T_094a7_row4_col1, #T_094a7_row4_col2, #T_094a7_row4_col3, #T_094a7_row4_col4, #T_094a7_row4_col5, #T_094a7_row4_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_094a7">
#   <thead>
#     <tr>
#       <th id="T_094a7_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_094a7_level0_col1" class="col_heading level0 col1" >Fácil AC (%)</th>
#       <th id="T_094a7_level0_col2" class="col_heading level0 col2" >Média AC (%)</th>
#       <th id="T_094a7_level0_col3" class="col_heading level0 col3" >Difícil AC (%)</th>
#       <th id="T_094a7_level0_col4" class="col_heading level0 col4" >Tokens (Média)</th>
#       <th id="T_094a7_level0_col5" class="col_heading level0 col5" >Custo Médio (US$)</th>
#       <th id="T_094a7_level0_col6" class="col_heading level0 col6" >Tempo Médio (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_094a7_row0_col0" class="data row0 col0" >Claude Sonnet 4.6</td>
#       <td id="T_094a7_row0_col1" class="data row0 col1" >77.61</td>
#       <td id="T_094a7_row0_col2" class="data row0 col2" >74.07</td>
#       <td id="T_094a7_row0_col3" class="data row0 col3" >36.36</td>
#       <td id="T_094a7_row0_col4" class="data row0 col4" >1698</td>
#       <td id="T_094a7_row0_col5" class="data row0 col5" >0.0121</td>
#       <td id="T_094a7_row0_col6" class="data row0 col6" >9</td>
#     </tr>
#     <tr>
#       <td id="T_094a7_row1_col0" class="data row1 col0" >GPT 5.4</td>
#       <td id="T_094a7_row1_col1" class="data row1 col1" >80.60</td>
#       <td id="T_094a7_row1_col2" class="data row1 col2" >67.90</td>
#       <td id="T_094a7_row1_col3" class="data row1 col3" >27.27</td>
#       <td id="T_094a7_row1_col4" class="data row1 col4" >1123</td>
#       <td id="T_094a7_row1_col5" class="data row1 col5" >0.0059</td>
#       <td id="T_094a7_row1_col6" class="data row1 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_094a7_row2_col0" class="data row2 col0" >Gemini 3.1 Pro</td>
#       <td id="T_094a7_row2_col1" class="data row2 col1" >97.01</td>
#       <td id="T_094a7_row2_col2" class="data row2 col2" >87.65</td>
#       <td id="T_094a7_row2_col3" class="data row2 col3" >75.76</td>
#       <td id="T_094a7_row2_col4" class="data row2 col4" >5128</td>
#       <td id="T_094a7_row2_col5" class="data row2 col5" >0.0520</td>
#       <td id="T_094a7_row2_col6" class="data row2 col6" >38</td>
#     </tr>
#     <tr>
#       <td id="T_094a7_row3_col0" class="data row3 col0" >Grok 4.20</td>
#       <td id="T_094a7_row3_col1" class="data row3 col1" >61.19</td>
#       <td id="T_094a7_row3_col2" class="data row3 col2" >53.09</td>
#       <td id="T_094a7_row3_col3" class="data row3 col3" >18.18</td>
#       <td id="T_094a7_row3_col4" class="data row3 col4" >1958</td>
#       <td id="T_094a7_row3_col5" class="data row3 col5" >0.0078</td>
#       <td id="T_094a7_row3_col6" class="data row3 col6" >9</td>
#     </tr>
#     <tr>
#       <td id="T_094a7_row4_col0" class="data row4 col0" >Mistral Small 4</td>
#       <td id="T_094a7_row4_col1" class="data row4 col1" >58.21</td>
#       <td id="T_094a7_row4_col2" class="data row4 col2" >48.15</td>
#       <td id="T_094a7_row4_col3" class="data row4 col3" >9.09</td>
#       <td id="T_094a7_row4_col4" class="data row4 col4" >1212</td>
#       <td id="T_094a7_row4_col5" class="data row4 col5" >0.0016</td>
#       <td id="T_094a7_row4_col6" class="data row4 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_combinado = pd.merge(question_img, question_noimg, on="Modelo", suffixes=(" (Com Img)", " (Sem Img)"))

# 3. REORDENAÇÃO DAS COLUNAS: Colocando as dificuldades equivalentes lado a lado
ordem_colunas = [
    "Modelo",
    "Fácil AC (%) (Com Img)",
    "Fácil AC (%) (Sem Img)",
    "Média AC (%) (Com Img)",
    "Média AC (%) (Sem Img)",
    "Difícil AC (%) (Com Img)",
    "Difícil AC (%) (Sem Img)"
]
df_combinado = df_combinado[ordem_colunas]

# 4. Ordenar os modelos em ordem alfabética
df_combinado = df_combinado.sort_values("Modelo").reset_index(drop=True)

# 5. Exibir com a estilização aplicada
display(
    df_combinado.style
    .format({
        "Fácil AC (%) (Com Img)":   "{:.2f}%",
        "Fácil AC (%) (Sem Img)":   "{:.2f}%",
        "Média AC (%) (Com Img)":   "{:.2f}%",
        "Média AC (%) (Sem Img)":   "{:.2f}%",
        "Difícil AC (%) (Com Img)": "{:.2f}%",
        "Difícil AC (%) (Sem Img)": "{:.2f}%",
    })
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# #T_11dd1 th {
#   text-align: center;
# }
# #T_11dd1_row0_col0, #T_11dd1_row0_col1, #T_11dd1_row0_col2, #T_11dd1_row0_col3, #T_11dd1_row0_col4, #T_11dd1_row0_col5, #T_11dd1_row0_col6, #T_11dd1_row1_col0, #T_11dd1_row1_col1, #T_11dd1_row1_col2, #T_11dd1_row1_col3, #T_11dd1_row1_col4, #T_11dd1_row1_col5, #T_11dd1_row1_col6, #T_11dd1_row2_col0, #T_11dd1_row2_col1, #T_11dd1_row2_col2, #T_11dd1_row2_col3, #T_11dd1_row2_col4, #T_11dd1_row2_col5, #T_11dd1_row2_col6, #T_11dd1_row3_col0, #T_11dd1_row3_col1, #T_11dd1_row3_col2, #T_11dd1_row3_col3, #T_11dd1_row3_col4, #T_11dd1_row3_col5, #T_11dd1_row3_col6, #T_11dd1_row4_col0, #T_11dd1_row4_col1, #T_11dd1_row4_col2, #T_11dd1_row4_col3, #T_11dd1_row4_col4, #T_11dd1_row4_col5, #T_11dd1_row4_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_11dd1">
#   <thead>
#     <tr>
#       <th id="T_11dd1_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_11dd1_level0_col1" class="col_heading level0 col1" >Fácil AC (%) (Com Img)</th>
#       <th id="T_11dd1_level0_col2" class="col_heading level0 col2" >Fácil AC (%) (Sem Img)</th>
#       <th id="T_11dd1_level0_col3" class="col_heading level0 col3" >Média AC (%) (Com Img)</th>
#       <th id="T_11dd1_level0_col4" class="col_heading level0 col4" >Média AC (%) (Sem Img)</th>
#       <th id="T_11dd1_level0_col5" class="col_heading level0 col5" >Difícil AC (%) (Com Img)</th>
#       <th id="T_11dd1_level0_col6" class="col_heading level0 col6" >Difícil AC (%) (Sem Img)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_11dd1_row0_col0" class="data row0 col0" >Claude Sonnet 4.6</td>
#       <td id="T_11dd1_row0_col1" class="data row0 col1" >83.58%</td>
#       <td id="T_11dd1_row0_col2" class="data row0 col2" >77.61%</td>
#       <td id="T_11dd1_row0_col3" class="data row0 col3" >71.60%</td>
#       <td id="T_11dd1_row0_col4" class="data row0 col4" >74.07%</td>
#       <td id="T_11dd1_row0_col5" class="data row0 col5" >30.30%</td>
#       <td id="T_11dd1_row0_col6" class="data row0 col6" >36.36%</td>
#     </tr>
#     <tr>
#       <td id="T_11dd1_row1_col0" class="data row1 col0" >GPT 5.4</td>
#       <td id="T_11dd1_row1_col1" class="data row1 col1" >82.09%</td>
#       <td id="T_11dd1_row1_col2" class="data row1 col2" >80.60%</td>
#       <td id="T_11dd1_row1_col3" class="data row1 col3" >69.14%</td>
#       <td id="T_11dd1_row1_col4" class="data row1 col4" >67.90%</td>
#       <td id="T_11dd1_row1_col5" class="data row1 col5" >30.30%</td>
#       <td id="T_11dd1_row1_col6" class="data row1 col6" >27.27%</td>
#     </tr>
#     <tr>
#       <td id="T_11dd1_row2_col0" class="data row2 col0" >Gemini 3.1 Pro</td>
#       <td id="T_11dd1_row2_col1" class="data row2 col1" >97.01%</td>
#       <td id="T_11dd1_row2_col2" class="data row2 col2" >97.01%</td>
#       <td id="T_11dd1_row2_col3" class="data row2 col3" >87.65%</td>
#       <td id="T_11dd1_row2_col4" class="data row2 col4" >87.65%</td>
#       <td id="T_11dd1_row2_col5" class="data row2 col5" >78.79%</td>
#       <td id="T_11dd1_row2_col6" class="data row2 col6" >75.76%</td>
#     </tr>
#     <tr>
#       <td id="T_11dd1_row3_col0" class="data row3 col0" >Grok 4.20</td>
#       <td id="T_11dd1_row3_col1" class="data row3 col1" >73.13%</td>
#       <td id="T_11dd1_row3_col2" class="data row3 col2" >61.19%</td>
#       <td id="T_11dd1_row3_col3" class="data row3 col3" >53.09%</td>
#       <td id="T_11dd1_row3_col4" class="data row3 col4" >53.09%</td>
#       <td id="T_11dd1_row3_col5" class="data row3 col5" >15.15%</td>
#       <td id="T_11dd1_row3_col6" class="data row3 col6" >18.18%</td>
#     </tr>
#     <tr>
#       <td id="T_11dd1_row4_col0" class="data row4 col0" >Mistral Small 4</td>
#       <td id="T_11dd1_row4_col1" class="data row4 col1" >61.19%</td>
#       <td id="T_11dd1_row4_col2" class="data row4 col2" >58.21%</td>
#       <td id="T_11dd1_row4_col3" class="data row4 col3" >41.98%</td>
#       <td id="T_11dd1_row4_col4" class="data row4 col4" >48.15%</td>
#       <td id="T_11dd1_row4_col5" class="data row4 col5" >12.12%</td>
#       <td id="T_11dd1_row4_col6" class="data row4 col6" >9.09%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Acertos por tópicos: grafos e programação dinâmica
# ---

# %%
total = 0

for key, data in dataset.items():
    total_cost = 0

    for count_test in data["cost_prompt"]:
        total_cost += count_test
    
    total += total_cost
    
    print(f"Total do custo [{key}]: U$ {total_cost:.2f}")
    
print(f"Valor gasto atualmente: U$ {total:.2f}")
# Out:
# Total do custo [results_anthropic_claude_sonnet_4_6_python_zero_img]: U$ 2.67
# Total do custo [results_anthropic_claude_sonnet_4_6_python_zero_noimg]: U$ 2.19
# Total do custo [results_google_gemini_3_1_pro_preview_python_zero_img]: U$ 10.26
# Total do custo [results_google_gemini_3_1_pro_preview_python_zero_noimg]: U$ 9.42
# Total do custo [results_gpt_5_4_python_zero_img]: U$ 1.17
# Total do custo [results_gpt_5_4_python_zero_noimg]: U$ 1.07
# Total do custo [results_mistralai_mistral_small_2603_python_zero_img]: U$ 0.32
# Total do custo [results_mistralai_mistral_small_2603_python_zero_noimg]: U$ 0.29
# Total do custo [results_x_ai_grok_4_20_python_zero_img]: U$ 1.10
# Total do custo [results_x_ai_grok_4_20_python_zero_noimg]: U$ 1.41
# Valor gasto atualmente: U$ 29.91

# %%
topics_unique = set()

for problem in problems:
    for topic in problem["topics"]:
        topics_unique.add(topic)
        
print(topics_unique)
# Out:
# {'convex hull trick', 'somas', 'ordenação', 'matemática', 'bitwise', 'algoritmos gulosos', 'árvore de fenwick', 'Programação Dinâmica', 'somas de prefixo', 'backtracking', 'algoritmo de dijkstra', 'programação dinâmica', 'dois ponteiros', 'LCA', 'Lógica', 'autômato celular', 'dfs/bfs', 'árvore geradora mínima', 'Busca em Largura', 'arredondamento', 'estruturas condicionais', 'busca binária', 'inversões', 'estrutura de dados', 'busca em largura', 'caminho mínimo', 'componentes conexas', 'kadane', 'busca exaustiva', 'grafos', 'queries', 'teoria dos números', 'Interseção de Retângulos', 'brute force', 'geometria espacial', 'estruturas de dados', 'lazy propagation', 'Busca em Profundidade (DFS)', 'loops', 'flood fill', 'Grafos', 'ad-hoc', 'hashing', 'otimização', 'comparação', 'fórmulas', 'pilha', 'busca em grade', 'ad hoc', 'recursão', 'BFS/DFS', 'implementação', 'pré-processamento', 'simulação', 'Ad-hoc', 'força bruta', 'fenwick tree', 'condicionais', 'mapeamento', 'diâmetro', 'Árvore Geradora Mínima', 'busca em largura (bfs)', 'contagem de inversões', 'vetores', 'array', 'combinatória', 'busca', 'dfs', 'Força Bruta', 'array circular', 'arrays', 'árvore de segmentos', 'strings', 'Árvores', 'Geometria', 'busca em grafos', 'bfs', 'busca em profundidade', 'componentes fortemente conexos', 'árvores', 'Array', 'componentes conexos', 'condicional', 'greedy', 'aritmética modular', 'geometria computacional', 'sweep line', 'soma de prefixos', 'matrizes', 'Backtracking', 'Simulação', 'matriz', 'Matemática', 'geometria', 'permutações', 'contagem', 'mediana', 'Geometria Computacional', 'teoria dos jogos', 'mathematics', 'lógica', 'two pointers', 'dijkstra', 'guloso'}

# %%
topics = []

for problem in problems:
    if problem.get("topics") is not None:
        topics.extend(problem["topics"])

print(set(topics))

topics_grafos = [
    'grafos', 
    'ciclos em grafos', 
    'busca em largura', 
    'busca em profundidade',
    'caminho mínimo', 
    'árvore geradora mínima', 
    'dijkstra', 
    'Busca em Profundidade (DFS)', 
    'diâmetro', 
    'Árvore Geradora Mínima', 
    'LCA', 
    'algoritmo de dijkstra', 
    'árvores', 
    'BFS/DFS', 
    'Grafos', 
    'Busca em Largura', 
    'bfs', 
    'componentes conexos', 
    'Árvores', 
    'componentes fortemente conexos', 
    'busca em largura (bfs)', 
    'dfs/bfs', 
    'componentes conexas', 
    'busca em grafos', 
    'flood fill', 
    'dfs'
]

topics_pd = [
    'programação dinâmica',
    'Programação Dinâmica', 
    'kadane', 
    'convex hull trick'
]

questions_by_topics = {"g": set(), "pd": set()}

for name, problem in zip(questions_name, problems):
    topicos = [t.lower() for t in problem.get('topics', [])]
    if any(t in topics_grafos for t in topicos):
        questions_by_topics["g"].add(name)
    elif any(t in topics_pd for t in topicos):
        questions_by_topics["pd"].add(name)

print(questions_by_topics)
print(f"grafos: {len(questions_by_topics['g'])}, programação dinâmica: {len(questions_by_topics['pd'])}")
# Out:
# {'convex hull trick', 'somas', 'ordenação', 'matemática', 'bitwise', 'algoritmos gulosos', 'árvore de fenwick', 'Programação Dinâmica', 'somas de prefixo', 'backtracking', 'algoritmo de dijkstra', 'programação dinâmica', 'dois ponteiros', 'LCA', 'Lógica', 'autômato celular', 'dfs/bfs', 'árvore geradora mínima', 'Busca em Largura', 'arredondamento', 'estruturas condicionais', 'busca binária', 'inversões', 'estrutura de dados', 'busca em largura', 'caminho mínimo', 'componentes conexas', 'kadane', 'busca exaustiva', 'grafos', 'queries', 'teoria dos números', 'Interseção de Retângulos', 'brute force', 'geometria espacial', 'estruturas de dados', 'lazy propagation', 'Busca em Profundidade (DFS)', 'loops', 'flood fill', 'Grafos', 'ad-hoc', 'hashing', 'otimização', 'comparação', 'fórmulas', 'pilha', 'busca em grade', 'ad hoc', 'recursão', 'BFS/DFS', 'implementação', 'pré-processamento', 'simulação', 'Ad-hoc', 'força bruta', 'fenwick tree', 'condicionais', 'mapeamento', 'diâmetro', 'Árvore Geradora Mínima', 'busca em largura (bfs)', 'contagem de inversões', 'vetores', 'array', 'combinatória', 'busca', 'dfs', 'Força Bruta', 'array circular', 'arrays', 'árvore de segmentos', 'strings', 'Árvores', 'Geometria', 'busca em grafos', 'bfs', 'busca em profundidade', 'componentes fortemente conexos', 'árvores', 'Array', 'componentes conexos', 'condicional', 'greedy', 'aritmética modular', 'geometria computacional', 'sweep line', 'soma de prefixos', 'matrizes', 'Backtracking', 'Simulação', 'matriz', 'Matemática', 'geometria', 'permutações', 'contagem', 'mediana', 'Geometria Computacional', 'teoria dos jogos', 'mathematics', 'lógica', 'two pointers', 'dijkstra', 'guloso'}
# {'g': {'Tesouro', 'Visita entre cidades', 'Metrônibus', 'Catálogo de Músicas', 'Duende Perdido', 'Toupeira', 'Viagem', 'Fissura Perigosa', 'Castelos da Nlogônia', 'Setas', 'Caminhos do reino', 'Jogo do Preto e Branco', 'Fast-Food', 'Copa do Mundo', 'Dengue', 'Móbile', 'O Chefe', 'Frete da Família Silva', 'Passa Bolinha', 'Ônibus', 'Frete', 'Capitais', 'Construção de Rodovia', 'Câmara de Compensação', 'Costa', 'Transportes', 'Fuga', 'Transmissão de Energia', 'Dividindo o império', 'Rede ótica', 'Burocracia', 'Pulo do Gato', 'Carro elétrico', 'Baldes', 'Metrô da Nlogônia', 'Fitas Verde-amarelas', 'Manchas de pele', 'Relógios', 'Sr. Sapo', 'Sr. Toupeira', 'Rodovia_2022', 'Dominó', 'Linhas de Ônibus', 'Mina', 'Chuva_2019', 'Quebra-cabeça', 'Reduzindo detalhes em um mapa', 'Toca do Saci', 'Dona Minhoca', 'Caminho das Pontes', 'Wifi', 'Câmeras', 'Mancha'}, 'pd': {'Macacos me mordam!', 'Forja de ORicalco', 'Brigadeiros', 'Taxa', 'Muro', 'Pizza', 'Distância entre amigos', 'Remove Dígitos', 'Trio de Bonecas', 'Calçada Imperial', 'Corredor'}}
# grafos: 53, programação dinâmica: 11

# %%
#Pegando só as questões de grafos e pd por nome
total_test_cases = {'g': 0, 'pd': 0}
for _, row in dataset["results_x_ai_grok_4_20_python_zero_img"].iterrows():
    if row["question_name"] in list(questions_by_topics['g']):
        total_test_cases['g'] += row['total_test_cases']
    elif row["question_name"] in questions_by_topics['pd']:
        total_test_cases['pd'] += row['total_test_cases']

print(f"Total de casos de teste dessa lista: {total_test_cases['g'] + total_test_cases['pd']}")
# Out:
# Total de casos de teste dessa lista: 2491

# %%
data_by_dataset = {}
for key, data in dataset.items():
    data_by_dataset[key] = {'g': 0, 'pd': 0}
    
    df = pd.DataFrame(data)
    df = df[df["judge_predict"] == "AC"]
    df.head()
    
    for _, row in df.iterrows():
        if row["question_name"] in list(questions_by_topics['g']):
            data_by_dataset[key]['g'] += row['AC']
        elif row["question_name"] in questions_by_topics['pd']:
            data_by_dataset[key]['pd'] += row['AC']

for key, value in data_by_dataset.items():
    print(f"{key}: {value}")
# Out:
# results_anthropic_claude_sonnet_4_6_python_zero_img: {'g': 1073, 'pd': 199}
# results_anthropic_claude_sonnet_4_6_python_zero_noimg: {'g': 1174, 'pd': 158}
# results_google_gemini_3_1_pro_preview_python_zero_img: {'g': 1532, 'pd': 486}
# results_google_gemini_3_1_pro_preview_python_zero_noimg: {'g': 1552, 'pd': 349}
# results_gpt_5_4_python_zero_img: {'g': 1008, 'pd': 194}
# results_gpt_5_4_python_zero_noimg: {'g': 950, 'pd': 174}
# results_mistralai_mistral_small_2603_python_zero_img: {'g': 506, 'pd': 80}
# results_mistralai_mistral_small_2603_python_zero_noimg: {'g': 621, 'pd': 108}
# results_x_ai_grok_4_20_python_zero_img: {'g': 856, 'pd': 90}
# results_x_ai_grok_4_20_python_zero_noimg: {'g': 846, 'pd': 90}

# %%
len_g = total_test_cases['g']
len_pd = total_test_cases['pd']
total_len = len_g + len_pd

base_models = set()
for k in data_by_dataset.keys():
    if k.endswith('_noimg'):
        base_models.add(k.replace('_noimg', ''))
    elif k.endswith('_img'):
        base_models.add(k.replace('_img', ''))

def get_total_base(base):
    t = 0
    if base + '_noimg' in data_by_dataset:
        t += data_by_dataset[base + '_noimg']['g'] + data_by_dataset[base + '_noimg']['pd']
    if base + '_img' in data_by_dataset:
        t += data_by_dataset[base + '_img']['g'] + data_by_dataset[base + '_img']['pd']
    return t

modelos_sorted = sorted(list(base_models), key=get_total_base, reverse=True)

pct_noimg = []
pct_img = []

for base in modelos_sorted:
    k_noimg = base + '_noimg'
    k_img = base + '_img'
    
    if k_noimg in data_by_dataset:
        total_acertos = data_by_dataset[k_noimg]['g'] + data_by_dataset[k_noimg]['pd']
        pct_noimg.append(total_acertos / total_len * 100)
    else:
        pct_noimg.append(0)
        
    # Preenche dados Com Imagem (ou 0 se não existir)
    if k_img in data_by_dataset:
        total_acertos = data_by_dataset[k_img]['g'] + data_by_dataset[k_img]['pd']
        pct_img.append(total_acertos / total_len * 100)
    else:
        pct_img.append(0)

x = np.arange(len(modelos_sorted))
w = 0.35

fig, ax = plt.subplots(figsize=(14, 6))

bars_noimg = ax.bar(x - w/2, pct_noimg, w, label='Sem imagem', color='#E63946')

bars_img = ax.bar(x + w/2, pct_img, w, label='Com imagem', color='#378ADD')

for i in range(len(modelos_sorted)):
    if pct_noimg[i] > 0:
        ax.text(x[i] - w/2, pct_noimg[i] + 1.5, f'{pct_noimg[i]:.1f}%',
                ha='center', va='bottom', fontsize=9, color='gray', fontweight='bold')
    
    if pct_img[i] > 0:
        ax.text(x[i] + w/2, pct_img[i] + 1.5, f'{pct_img[i]:.1f}%',
                ha='center', va='bottom', fontsize=9, color='gray', fontweight='bold')

ax.set_xticks(x)
ax.set_xticklabels(modelos_sorted, rotation=30, ha='right', fontsize=10)
ax.set_ylabel('% de acertos totais')
ax.set_ylim(0, 100)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda v, _: f'{v:.0f}%'))

ax.legend(loc='upper right')
ax.grid(axis='y', alpha=0.2)
ax.spines[['top', 'right']].set_visible(False)

plt.tight_layout()
plt.show()
